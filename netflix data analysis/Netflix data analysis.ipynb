# %% [markdown]
# ### Netflix shows analysis

# %%
# Importing the dataset
import pandas as pd
shows = pd.read_csv(r"C:\Users\Anzi\OneDrive\Desktop\New folder (5)\netflix_titles.csv") # include 'r' to remove unicode error
shows
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Top-5 rows of the dataset
shows.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Top-5 bottom rows of the dataset
shows.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# No. of rows and columns
shows.shape
# Out:
# (8807, 12)

# %%
# Total values in the dataset
shows.size
# Out:
# 105684

# %%
# Column names
shows.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Data-types of each columns
shows.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# Information of dataset
shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Finding the duplicate records
shows.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
shows[shows.duplicated()] # no duplicate records
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# Null values in th dataset
shows.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
# Count of null values
print(shows.isnull().sum())
# Representation of null values

import seaborn as sns
sns.heatmap(shows.isnull())
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
# <Axes: >

# %%
# Information for a particular dataset
shows[shows['title'].isin(['Zodiac'])]
# Out:
#      show_id   type   title       director  \
# 8802   s8803  Movie  Zodiac  David Fincher
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
#
#              date_added  release_year rating duration  \
# 8802  November 20, 2019          2007      R  158 min
#
#                            listed_in  \
# 8802  Cult Movies, Dramas, Thrillers
#
#                                             description
# 8802  A political cartoonist, a crime reporter and a...

# %%
shows[shows['title'].str.contains('Zodiac')]
# Out:
#      show_id     type                                title       director  \
# 2998   s2999  TV Show  ​SAINT SEIYA: Knights of the Zodiac            NaN
# 8802   s8803    Movie                               Zodiac  David Fincher
#
#                                                    cast        country  \
# 2998  Bryson Baugus, Emily Neves, Blake Shepard, Pat...          Japan
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
#
#              date_added  release_year rating   duration  \
# 2998   January 23, 2020          2020  TV-14  2 Seasons
# 8802  November 20, 2019          2007      R    158 min
#
#                                  listed_in  \
# 2998  Anime Series, International TV Shows
# 8802        Cult Movies, Dramas, Thrillers
#
#                                             description
# 2998  Seiya and the Knights of the Zodiac rise again...
# 8802  A political cartoonist, a crime reporter and a...

# %% [markdown]
# ## Date format change

# %%
shows['date'] = pd.to_datetime(shows['date_added'] ,errors ='coerce')
shows
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
shows.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# date            datetime64[ns]
# dtype: object

# %% [markdown]
# ## Year counts

# %%
# Year in which maximum number of Tv shows and movies released

shows['date'].dt.year.value_counts()
# Out:
# date
# 2019.0    1999
# 2020.0    1878
# 2018.0    1625
# 2021.0    1498
# 2017.0    1164
# 2016.0     418
# 2015.0      73
# 2014.0      23
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# ## To plot in bar graph

# %%
shows['date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='date'>

# %%
### To check the number of movies and Tv shows in the dataset

# %%
shows.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
shows.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
## Plot in a bar graph

sns.countplot(shows['type'])
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %% [markdown]
# ### Filtering

# %%
## movies released on 2019
shows[(shows['type']== 'Movie') & (shows['release_year']==2019)]
# Out:
#      show_id   type                                 title  \
# 3077   s3078  Movie                                Aaviri
# 3078   s3079  Movie  Albert Pinto Ko Gussa Kyun Aata Hai?
# 3080   s3081  Movie        Benchwarmers 2: Breaking Balls
# 3081   s3082  Movie                            How High 2
# 3089   s3090  Movie           Hot Gimmick: Girl Meets Boy
# ...      ...    ...                                   ...
# 8793   s8794  Movie                  Yours, Mine and Ours
# 8798   s8799  Movie                              Zed Plus
# 8802   s8803  Movie                                Zodiac
# 8804   s8805  Movie                            Zombieland
# 8806   s8807  Movie                                Zubaan
#
#                      director  \
# 3077                Ravi Babu
# 3078          Soumitra Ranade
# 3080            Jon Rosenbaum
# 3081              Bruce Leddy
# 3089              Yuki Yamato
# ...                       ...
# 8793             Raja Gosnell
# ...

# %%
## titles of all TV shows that were released in United States only

shows.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021        2021.0  PG-13     90 min
# 1  September 24, 2021        2021.0  TV-MA  2 Seasons
# 2  September 24, 2021        2021.0  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
shows[(shows['type']=='TV Show') & (shows['country']=='United States')]['title']
# Out:
# 15                           Dear White People
# 40      He-Man and the Masters of the Universe
# 55                                   Nailed It
# 67                           Saved by the Bell
# 82                                     Lucifer
#                          ...
# 8710                                     Weeds
# 8726                      When Calls the Heart
# 8747                                 Winsanity
# 8755                         Women Behind Bars
# 8780                              Yo-Kai Watch
# Name: title, Length: 760, dtype: object

# %%
## Top 10 director names of Tv shows and movies

# %%
shows['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
## Category movies and types or in  UK

shows.head(10)
shows[(shows['type']=='Movie') &(shows['listed_in']=='Comedies')]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %%
shows[(shows['type']=='Movie') &(shows['listed_in']=='Comedies') | (shows['country']=='United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
### Number of movies/shows cast by Tom cruise

shows[shows('cast').str('Tom Cruise')] # no sepcific movie alone cast by Tom cruise so change the data into another  dataframe
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 35 line 3
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X52sdW50aXRsZWQ%3D?line=0'>1</a> ### Number of movies/shows cast by Tom cruise
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X52sdW50aXRsZWQ%3D?line=2'>3</a> shows[shows('cast').str('Tom Cruise')]
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# ### Creating new dataframe

# %%
shows_new = shows.dropna()  # remove all null values

# %%
shows_new.head(5)
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
shows_new[shows_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021        2021.0      R  189 min
# 1254   March 1, 2021        2021.0      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description       date    year
# 341   Through chance, history and divine interventio... 2021-08-01  2021.0
# 1254  Motivated by money, a selfish workaholic seeki... 2021-03-01  2021.0

# %%
## Ratings of the movies and tv shows
shows['rating'].nunique()  # number of unique rating
# Out:
# 17

# %%
shows['rating'].unique()  # types of 17 diferent rating
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
shows.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021        2021.0  PG-13     90 min
# 1  September 24, 2021        2021.0  TV-MA  2 Seasons
# 2  September 24, 2021        2021.0  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
## Number of movies that has 'PG' rating in India

shows[(shows['type']=='Movie') & (shows['rating']=='PG')].shape
# Out:
# (287, 14)

# %%
shows[(shows['type']=='Movie') & (shows['rating']=='PG') & (shows['country'] =='India')]
# Out:
#      show_id   type             title          director  \
# 1022   s1023  Movie  Taare Zameen Par        Aamir Khan
# 4466   s4467  Movie          Zokkomon  Satyajit Bhatkal
#
#                                                    cast country  \
# 1022  Aamir Khan, Darsheel Safary, Tanay Chheda, Tis...   India
# 4466  Darsheel Safary, Anupam Kher, Manjari Fadnis, ...   India
#
#             date_added  release_year rating duration  \
# 1022    April 17, 2021        2021.0     PG  162 min
# 4466  November 1, 2018        2018.0     PG  104 min
#
#                              listed_in  \
# 1022      Dramas, International Movies
# 4466  Children & Family Movies, Dramas
#
#                                             description       date    year
# 1022  When daydreamer Ishaan is sent to boarding sch... 2021-04-17  2021.0
# 4466  When his cruel uncle abandons him, a young orp... 2018-11-01  2018.0

# %%
## Number of TV shows with R rating after the year 2018
shows[(shows['type']=='TV Show') & (shows['rating']=='R') & (shows['release_year']> 2018)]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#           date_added  release_year rating  duration listed_in  \
# 3893  April 25, 2019        2019.0      R  1 Season  TV Shows
#
#                                             description       date    year
# 3893  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
## maximum duration of movies/tv shows

shows.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
shows.duration.dtypes # convert the datatype into minutes and seasons
shows[['Minutes', 'Unit']] = shows['duration'].str.split(' ', expand = True)
shows.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021        2021.0  PG-13     90 min
# 1  September 24, 2021        2021.0  TV-MA  2 Seasons
# 2  September 24, 2021        2021.0  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
shows['Minutes'] = shows['Minutes'].apply(float) # covert minutes into float datatype
shows['Minutes'].max()
# Out:
# 312.0

# %%
shows['Minutes'].min()
# Out:
# 1.0

# %%
shows['Minutes'].mean()
# Out:
# 69.84688777828259

# %%
### Country with highest number of TV Shows 

shows_tvshow = shows[shows['type'] == 'TV Show']
shows_tvshow.head(3)

shows_tvshow.country.value_counts()
# Out:
# country
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 196, dtype: int64

# %%
shows_tvshow.country.value_counts().head(3)
# Out:
# country
# United States     760
# United Kingdom    213
# Japan             169
# Name: count, dtype: int64

# %%
## sort the dataset by year

shows.sort_values(by = 'year', ascending = False)
# Out:
#      show_id     type                               title         director  \
# 0         s1    Movie                Dick Johnson Is Dead  Kirsten Johnson
# 996     s997    Movie                          HOMUNCULUS  Takashi Shimizu
# 1005   s1006    Movie  Keymon and Nani in Space Adventure              NaN
# 1004   s1005  TV Show                  Izzy's Koala World              NaN
# 1003   s1004  TV Show                                Zero              NaN
# ...      ...      ...                                 ...              ...
# 8539   s8540  TV Show                          The Tudors              NaN
# 8557   s8558  TV Show                       The West Wing              NaN
# 8684   s8685  TV Show                             Vroomiz              NaN
# 8712   s8713  TV Show          Weird Wonders of the World              NaN
# 8755   s8756  TV Show                   Women Behind Bars              NaN
#
#                                                    cast  \
# ...

# %%
# Types of Movie under the category Dramas or tv shows in kids tv
shows.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021        2021.0  PG-13     90 min
# 1  September 24, 2021        2021.0  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description       date    year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#    Minutes    Units     Unit
# ...

# %%
shows[(shows['type'] =='Movie' ) & (shows['listed_in'] =='Dramas')].head(5)
# Out:
#     show_id   type                title             director  \
# 112    s113  Movie                Worth       Sara Colangelo
# 129    s130  Movie   An Unfinished Life      Lasse Hallström
# 142    s143  Movie      Freedom Writers  Richard LaGravenese
# 162    s163  Movie             Marshall      Reginald Hudlin
# 329    s330  Movie  Catch Me If You Can     Steven Spielberg
#
#                                                   cast  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
# 142  Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# 162  Chadwick Boseman, Josh Gad, Kate Hudson, Sterl...
# 329  Leonardo DiCaprio, Tom Hanks, Christopher Walk...
#
#                              country         date_added  release_year rating  \
# 112                              NaN  September 3, 2021        2021.0  PG-13
# 129           Germany, United States  September 1, 2021        2021.0  PG-13
# ...

# %%
shows[(shows['type'] =='TV Show' ) & (shows['listed_in'] =="Kids' TV")].head(5)
# Out:
#     show_id     type                    title director  \
# 34      s35  TV Show  Tayo and Little Wizards      NaN
# 39      s40  TV Show             Chhota Bheem      NaN
# 65      s66  TV Show             Numberblocks      NaN
# 89      s90  TV Show              Mighty Raju      NaN
# 100    s101  TV Show  Tobot Galaxy Detectives      NaN
#
#                                                   cast         country  \
# 34   Dami Lee, Jason Lee, Bommie Catherine Han, Jen...             NaN
# 39   Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...           India
# 65   Beth Chalmers, David Holt, Marcel McCalla, Ter...  United Kingdom
# 89   Julie Tejwani, Sabina Malik, Jigna Bhardwaj, R...             NaN
# 100  Austin Abell, Travis Turner, Cole Howard, Anna...             NaN
#
#              date_added  release_year rating   duration listed_in  \
# 34   September 17, 2021        2021.0  TV-Y7   1 Season  Kids' TV
# 39   September 16, 2021        2021.0  TV-Y7  3 Seasons  Kids' TV
# ...

# %%
shows[(shows['type'] =='Movie' ) & (shows['listed_in'] =='Dramas')| (shows['type'] =='TV Show' ) & (shows['listed_in'] =="Kids' TV")].head(5)
# Out:
#     show_id     type                    title director  \
# 34      s35  TV Show  Tayo and Little Wizards      NaN
# 39      s40  TV Show             Chhota Bheem      NaN
# 65      s66  TV Show             Numberblocks      NaN
# 89      s90  TV Show              Mighty Raju      NaN
# 100    s101  TV Show  Tobot Galaxy Detectives      NaN
#
#                                                   cast         country  \
# 34   Dami Lee, Jason Lee, Bommie Catherine Han, Jen...             NaN
# 39   Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...           India
# 65   Beth Chalmers, David Holt, Marcel McCalla, Ter...  United Kingdom
# 89   Julie Tejwani, Sabina Malik, Jigna Bhardwaj, R...             NaN
# 100  Austin Abell, Travis Turner, Cole Howard, Anna...             NaN
#
#              date_added  release_year rating   duration listed_in  \
# 34   September 17, 2021        2021.0  TV-Y7   1 Season  Kids' TV
# 39   September 16, 2021        2021.0  TV-Y7  3 Seasons  Kids' TV
# ...
